# %%
1+1
# Out:
# 2

# %% [markdown]
# # Addition

# %%
# above option at code position select markdown option
a=2
b=3
c=a+b
c
# Out:
# 5

# %%
# a for adding row above b for adding row below and dd for deleting row 
# to start command mode press escape key , cell seen in blue color

# %%
pwd   # to know file location (print working directory)
# Out:
# 'C:\\Users\\Pratik Patade'
